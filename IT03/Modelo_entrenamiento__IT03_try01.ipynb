# %% [markdown]
# <a href="https://colab.research.google.com/github/Sisterno/ML_RedesNeuronales/blob/master/IT03/Modelo_entrenamiento__IT03_try01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from time import time
import pathlib

path_img_leucocitos = "/content/drive/MyDrive/ML/04-dataset-preprocesado-fusion";
pathlib_img_leucocitos=pathlib.Path(path_img_leucocitos)

from google.colab import drive
drive.mount('/content/drive')

# batch_size = 32
batch_size = 32
img_height = 180
img_width = 180

#-------------------------------------------------------------------------------
class TimingCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []
    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time()
    def on_epoch_end(self, batch, logs={}):
        self.times.append(time() - self.epoch_time_start)
#-------------------------------------------------------------------------------

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  path_img_leucocitos,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  path_img_leucocitos,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)

AUTOTUNE = tf.data.AUTOTUNE

# train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
# val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
# val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Modelo DS002-I03-D001

# %%
#-------------------------------------------------------------------------------
from time import time
cb_I03_D001 = TimingCallback()
num_classes = 5
epochs=50

model_I03_D001 = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(16, activation='relu'),
  layers.Dense(num_classes)
])
model_I03_D001.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D001.summary()


history_I03_D001 = model_I03_D001.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D001]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/50
# 1497/1497 [==============================] - 8729s 6s/step - loss: 1.5352 - accuracy: 0.5384 - val_loss: 0.8298 - val_accuracy: 0.6565
# Epoch 2/50
# 1497/1497 [==============================] - 119s 79ms/step - loss: 0.7692 - accuracy: 0.6799 - val_loss: 0.6990 - val_accuracy: 0.7155
# Epoch 3/50
# 1497/1497 [==============================] - 118s 79ms/step - loss: 0.6331 - accuracy: 0.7405 - val_loss: 0.5989 - val_accuracy: 0.7614
# Epoch 4/50
# 1497/1497 [==============================] - 118s 78ms/step - loss: 0.5362 - accuracy: 0.7792 - val_loss: 0.5409 - val_accuracy: 0.7789
# Epoch 5/50
# 1497/1497 [==============================] - 117s 78ms/step - loss: 0.4944 - accuracy: 0.7994 - val_loss: 0.4530 - val_accuracy: 0.8169
# Epoch 6/50
# 1497/1497 [==============================] - 117s 78ms/step - loss: 0.4404 - accuracy: 0.8261 - val_loss: 0.4581 - val_accuracy: 0.8198
# Epoch 7/50
# 1497/1497 [==============================] - 117s 78ms/step - loss: 0.3913 - accuracy: 0.8446 - val_loss: 0.4090 - val_accuracy: 0.8423
# Epoch 8/50
# 1497/1497 [==============================] - 116s 78ms/step - loss: 0.3623 - accuracy: 0.8552 - val_loss: 0.4008 - val_accuracy: 0.8444
# Epoch 9/50
# 1497/1497 [==============================] - 116s 77ms/step - loss: 0.3374 - accuracy: 0.8626 - val_loss: 0.3876 - val_accuracy: 0.8499
# Epoch 10/50
# 1497/1497 [==============================] - 117s 78ms/step - loss: 0.3144 - accuracy: 0.8698 - val_loss: 0.3557 - val_accuracy: 0.8586
# Epoch 11/50
# 1497/1497 [==============================] - 116s 78ms/step - loss: 0.3028 - accuracy: 0.8748 - val_loss: 0.3509 - val_accuracy: 0.8564
# Epoch 12/50
# 1497/1497 [==============================] - 116s 77ms/step - loss: 0.2914 - accuracy: 0.8782 - val_loss: 0.3293 - val_accuracy: 0.8686
# Epoch 13/50
# 1497/1497 [==============================] - 116s 77ms/step - loss: 0.2775 - accuracy: 0.8819 - val_loss: 0.3328 - val_accuracy: 0.8717
# Epoch 14/50
# 1497/1497 [==============================] - 116s 77ms/step - loss: 0.2773 - accuracy: 0.8834 - val_loss: 0.3413 - val_accuracy: 0.8697
# Epoch 15/50
# 1497/1497 [==============================] - 118s 79ms/step - loss: 0.2620 - accuracy: 0.8891 - val_loss: 0.3193 - val_accuracy: 0.8727
# Epoch 16/50
# 1497/1497 [==============================] - 120s 80ms/step - loss: 0.2553 - accuracy: 0.8918 - val_loss: 0.3592 - val_accuracy: 0.8656
# Epoch 17/50
# 1497/1497 [==============================] - 121s 80ms/step - loss: 0.2526 - accuracy: 0.8925 - val_loss: 0.3580 - val_accuracy: 0.8680
# Epoch 18/50
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2454 - accuracy: 0.8960 - val_loss: 0.3050 - val_accuracy: 0.8814
# Epoch 19/50
# 1497/1497 [==============================] - 124s 82ms/step - loss: 0.2358 - accuracy: 0.9006 - val_loss: 0.3187 - val_accuracy: 0.8754
# Epoch 20/50
# 1497/1497 [==============================] - 124s 82ms/step - loss: 0.2336 - accuracy: 0.9009 - val_loss: 0.3103 - val_accuracy: 0.8810
# Epoch 21/50
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.2270 - accuracy: 0.9033 - val_loss: 0.3439 - val_accuracy: 0.8645
# Epoch 22/50
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.2276 - accuracy: 0.9037 - val_loss: 0.4290 - val_accuracy: 0.8595
# Epoch 23/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.2188 - accuracy: 0.9075 - val_loss: 0.3743 - val_accuracy: 0.8721
# Epoch 24/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.2115 - accuracy: 0.9117 - val_loss: 0.3052 - val_accuracy: 0.8826
# Epoch 25/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.2168 - accuracy: 0.9077 - val_loss: 0.3012 - val_accuracy: 0.8858
# Epoch 26/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.2076 - accuracy: 0.9129 - val_loss: 0.3137 - val_accuracy: 0.8895
# Epoch 27/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.2040 - accuracy: 0.9145 - val_loss: 0.3371 - val_accuracy: 0.8853
# Epoch 28/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.2043 - accuracy: 0.9153 - val_loss: 0.3182 - val_accuracy: 0.8824
# Epoch 29/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1976 - accuracy: 0.9180 - val_loss: 0.3212 - val_accuracy: 0.8896
# Epoch 30/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1909 - accuracy: 0.9209 - val_loss: 0.3663 - val_accuracy: 0.8799
# Epoch 31/50
# 1497/1497 [==============================] - 127s 84ms/step - loss: 0.1903 - accuracy: 0.9215 - val_loss: 0.3210 - val_accuracy: 0.8884
# Epoch 32/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1862 - accuracy: 0.9237 - val_loss: 0.3941 - val_accuracy: 0.8770
# Epoch 33/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1793 - accuracy: 0.9258 - val_loss: 0.3316 - val_accuracy: 0.8899
# Epoch 34/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1762 - accuracy: 0.9277 - val_loss: 0.3471 - val_accuracy: 0.8857
# Epoch 35/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1760 - accuracy: 0.9290 - val_loss: 0.3156 - val_accuracy: 0.8987
# Epoch 36/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1772 - accuracy: 0.9275 - val_loss: 0.3388 - val_accuracy: 0.8904
# Epoch 37/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1709 - accuracy: 0.9317 - val_loss: 0.3084 - val_accuracy: 0.9001
# Epoch 38/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1649 - accuracy: 0.9339 - val_loss: 0.3693 - val_accuracy: 0.8864
# Epoch 39/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1644 - accuracy: 0.9341 - val_loss: 0.3368 - val_accuracy: 0.9004
# Epoch 40/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1617 - accuracy: 0.9363 - val_loss: 0.3409 - val_accuracy: 0.8970
# Epoch 41/50
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1584 - accuracy: 0.9390 - val_loss: 0.3551 - val_accuracy: 0.8943
# Epoch 42/50
# 1497/1497 [==============================] - 124s 82ms/step - loss: 0.1616 - accuracy: 0.9365 - val_loss: 0.3702 - val_accuracy: 0.8921
# Epoch 43/50
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.1554 - accuracy: 0.9392 - val_loss: 0.3992 - val_accuracy: 0.8882
# Epoch 44/50
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.1488 - accuracy: 0.9418 - val_loss: 0.3769 - val_accuracy: 0.8946
# Epoch 45/50
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.1547 - accuracy: 0.9405 - val_loss: 0.3552 - val_accuracy: 0.8939
# Epoch 46/50
# 1497/1497 [==============================] - 125s 84ms/step - loss: 0.1483 - accuracy: 0.9430 - val_loss: 0.3454 - val_accuracy: 0.8996
# Epoch 47/50
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1527 - accuracy: 0.9416 - val_loss: 0.3561 - val_accuracy: 0.8939
# Epoch 48/50
# 1497/1497 [==============================] - 127s 84ms/step - loss: 0.1393 - accuracy: 0.9459 - val_loss: 0.3894 - val_accuracy: 0.8951
# Epoch 49/50
# 1497/1497 [==============================] - 127s 85ms/step - loss: 0.1405 - accuracy: 0.9459 - val_loss: 0.4475 - val_accuracy: 0.8914
# Epoch 50/50
# 1497/1497 [==============================] - 127s 85ms/step - loss: 0.1436 - accuracy: 0.9461 - val_loss: 0.3797 - val_accuracy: 0.8990

# %%
#-------------------------------------------------------------------------------

print(cb_I03_D001.times)
final_time = 0
for time in cb_I03_D001.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D001.history['accuracy'])))
print('loss => '+ str(min(history_I03_D001.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D001.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D001.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D001.history['accuracy']
val_acc = history_I03_D001.history['val_accuracy']

loss=history_I03_D001.history['loss']
val_loss=history_I03_D001.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [8729.048716783524, 118.75945401191711, 117.9949209690094, 117.84145331382751, 116.77816581726074, 116.6380934715271, 116.70074963569641, 116.48341584205627, 115.94351983070374, 116.63906121253967, 116.41391658782959, 115.62006139755249, 115.86471009254456, 115.56962084770203, 117.9055118560791, 120.42596340179443, 120.66181230545044, 122.235684633255, 123.51940178871155, 123.79861116409302, 123.97238683700562, 124.07474660873413, 125.35071468353271, 125.51616430282593, 124.68429136276245, 124.94870567321777, 125.02675938606262, 125.59479999542236, 125.91260194778442, 125.05155491828918, 126.68639302253723, 126.02585577964783, 125.38827133178711, 125.88958477973938, 125.54884219169617, 125.9728856086731, 124.96864604949951, 125.69265580177307, 124.51245045661926, 125.00888657569885, 124.55065655708313, 123.79565167427063, 124.4154646396637, 124.47564744949341, 121.51015639305115, 125.46927690505981, 126.27532076835632, 126.52548384666443, 127.16436839103699, 127.46621632575989]
# El entrenamiento se demoro: 14732.318285226822 segundos
# El entrenamiento se demoro: 245.5386380871137 minutos
# accuracy => 0.946098268032074
# loss => 0.13930831849575043
# val_accuracy => 0.9003757834434509
# val_loss => 0.3011569380760193

# %% [markdown]
# ## Modelo DS002-I03-D002

# %%
#-------------------------------------------------------------------------------
from time import time
cb_I03_D002 = TimingCallback()
num_classes = 5
epochs=30

model_I03_D002 = Sequential([
  layers.Conv2D(8, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='sigmoid'),
  layers.Dense(num_classes)
])
model_I03_D002.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D002.summary()


history_I03_D002 = model_I03_D002.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D002]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/30
# 749/749 [==============================] - 115s 151ms/step - loss: 1.3643 - accuracy: 0.4242 - val_loss: 0.9448 - val_accuracy: 0.6020
# Epoch 2/30
# 749/749 [==============================] - 115s 152ms/step - loss: 0.8311 - accuracy: 0.6613 - val_loss: 0.7181 - val_accuracy: 0.7202
# Epoch 3/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.6963 - accuracy: 0.7255 - val_loss: 0.6361 - val_accuracy: 0.7509
# Epoch 4/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.6084 - accuracy: 0.7609 - val_loss: 0.5943 - val_accuracy: 0.7643
# Epoch 5/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.5561 - accuracy: 0.7839 - val_loss: 0.5325 - val_accuracy: 0.7912
# Epoch 6/30
# 749/749 [==============================] - 113s 150ms/step - loss: 0.5214 - accuracy: 0.8001 - val_loss: 0.5056 - val_accuracy: 0.8025
# Epoch 7/30
# 749/749 [==============================] - 114s 151ms/step - loss: 0.4913 - accuracy: 0.8114 - val_loss: 0.4942 - val_accuracy: 0.8063
# Epoch 8/30
# 749/749 [==============================] - 113s 150ms/step - loss: 0.4697 - accuracy: 0.8200 - val_loss: 0.5006 - val_accuracy: 0.8028
# Epoch 9/30
# 749/749 [==============================] - 113s 150ms/step - loss: 0.4467 - accuracy: 0.8293 - val_loss: 0.4550 - val_accuracy: 0.8249
# Epoch 10/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.4325 - accuracy: 0.8340 - val_loss: 0.4604 - val_accuracy: 0.8165
# Epoch 11/30
# 749/749 [==============================] - 113s 149ms/step - loss: 0.4158 - accuracy: 0.8410 - val_loss: 0.4584 - val_accuracy: 0.8176
# Epoch 12/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.4066 - accuracy: 0.8437 - val_loss: 0.4143 - val_accuracy: 0.8373
# Epoch 13/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.3885 - accuracy: 0.8522 - val_loss: 0.4175 - val_accuracy: 0.8351
# Epoch 14/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.3813 - accuracy: 0.8563 - val_loss: 0.3960 - val_accuracy: 0.8450
# Epoch 15/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.3711 - accuracy: 0.8597 - val_loss: 0.3958 - val_accuracy: 0.8475
# Epoch 16/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.3551 - accuracy: 0.8674 - val_loss: 0.3879 - val_accuracy: 0.8485
# Epoch 17/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.3493 - accuracy: 0.8702 - val_loss: 0.3927 - val_accuracy: 0.8472
# Epoch 18/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.3330 - accuracy: 0.8764 - val_loss: 0.3782 - val_accuracy: 0.8529
# Epoch 19/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.3242 - accuracy: 0.8802 - val_loss: 0.3920 - val_accuracy: 0.8462
# Epoch 20/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.3143 - accuracy: 0.8845 - val_loss: 0.3681 - val_accuracy: 0.8591
# Epoch 21/30
# 749/749 [==============================] - 113s 149ms/step - loss: 0.3079 - accuracy: 0.8876 - val_loss: 0.3530 - val_accuracy: 0.8663
# Epoch 22/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.2921 - accuracy: 0.8958 - val_loss: 0.3631 - val_accuracy: 0.8610
# Epoch 23/30
# 749/749 [==============================] - 112s 149ms/step - loss: 0.2849 - accuracy: 0.8968 - val_loss: 0.3603 - val_accuracy: 0.8568
# Epoch 24/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.2722 - accuracy: 0.9020 - val_loss: 0.3696 - val_accuracy: 0.8632
# Epoch 25/30
# 749/749 [==============================] - 113s 149ms/step - loss: 0.2568 - accuracy: 0.9088 - val_loss: 0.3245 - val_accuracy: 0.8797
# Epoch 26/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.2488 - accuracy: 0.9111 - val_loss: 0.3405 - val_accuracy: 0.8742
# Epoch 27/30
# 749/749 [==============================] - 112s 148ms/step - loss: 0.2468 - accuracy: 0.9122 - val_loss: 0.3285 - val_accuracy: 0.8785
# Epoch 28/30
# 749/749 [==============================] - 113s 150ms/step - loss: 0.2376 - accuracy: 0.9158 - val_loss: 0.3420 - val_accuracy: 0.8758
# Epoch 29/30
# 749/749 [==============================] - 113s 149ms/step - loss: 0.2271 - accuracy: 0.9206 - val_loss: 0.3135 - val_accuracy: 0.8837
# Epoch 30/30
# 749/749 [==============================] - 113s 149ms/step - loss: 0.2199 - accuracy: 0.9232 - val_loss: 0.3035 - val_accuracy: 0.8897

# %%
#-------------------------------------------------------------------------------

print(cb_I03_D002.times)
final_time = 0
for time in cb_I03_D002.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D002.history['accuracy'])))
print('loss => '+ str(min(history_I03_D002.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D002.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D002.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D002.history['accuracy']
val_acc = history_I03_D002.history['val_accuracy']

loss=history_I03_D002.history['loss']
val_loss=history_I03_D002.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [114.55880331993103, 114.67337369918823, 112.14787435531616, 112.1949872970581, 112.22354483604431, 112.86325764656067, 113.68888330459595, 112.92829823493958, 113.31439423561096, 112.10187864303589, 112.59541654586792, 111.78328609466553, 112.17263889312744, 112.30340528488159, 111.55926704406738, 112.14627480506897, 111.8170280456543, 112.43877983093262, 111.7127628326416, 111.95240330696106, 112.55238032341003, 112.0083966255188, 112.26378631591797, 111.92605328559875, 112.50234818458557, 112.01725149154663, 111.83227443695068, 112.85787987709045, 112.73997092247009, 112.57948803901672]
# El entrenamiento se demoro: 3374.456387758255 segundos
# El entrenamiento se demoro: 56.24093979597092 minutos
# accuracy => 0.9232391119003296
# loss => 0.2198794037103653
# val_accuracy => 0.8896868228912354
# val_loss => 0.30349329113960266

# %% [markdown]
# ## Modelo DS002-I03-D003

# %%
#-------------------------------------------------------------------------------
from time import time
cb_I03_D003 = TimingCallback()
num_classes = 5
epochs=35

model_I03_D003 = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(16, activation='relu'),
  layers.Dense(num_classes)
])
model_I03_D003.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D003.summary()


history_I03_D003 = model_I03_D003.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D003]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/35
# 1497/1497 [==============================] - 141s 83ms/step - loss: 0.9653 - accuracy: 0.6217 - val_loss: 0.6533 - val_accuracy: 0.7435
# Epoch 2/35
# 1497/1497 [==============================] - 120s 80ms/step - loss: 0.5733 - accuracy: 0.7768 - val_loss: 0.4628 - val_accuracy: 0.8215
# Epoch 3/35
# 1497/1497 [==============================] - 122s 82ms/step - loss: 0.4396 - accuracy: 0.8287 - val_loss: 0.4062 - val_accuracy: 0.8397
# Epoch 4/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.3881 - accuracy: 0.8481 - val_loss: 0.3636 - val_accuracy: 0.8600
# Epoch 5/35
# 1497/1497 [==============================] - 121s 81ms/step - loss: 0.3529 - accuracy: 0.8615 - val_loss: 0.3288 - val_accuracy: 0.8717
# Epoch 6/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.3266 - accuracy: 0.8704 - val_loss: 0.3081 - val_accuracy: 0.8787
# Epoch 7/35
# 1497/1497 [==============================] - 121s 81ms/step - loss: 0.3068 - accuracy: 0.8769 - val_loss: 0.3239 - val_accuracy: 0.8764
# Epoch 8/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2988 - accuracy: 0.8821 - val_loss: 0.2964 - val_accuracy: 0.8875
# Epoch 9/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2858 - accuracy: 0.8868 - val_loss: 0.2907 - val_accuracy: 0.8874
# Epoch 10/35
# 1497/1497 [==============================] - 121s 81ms/step - loss: 0.2764 - accuracy: 0.8903 - val_loss: 0.3073 - val_accuracy: 0.8809
# Epoch 11/35
# 1497/1497 [==============================] - 121s 81ms/step - loss: 0.2628 - accuracy: 0.8960 - val_loss: 0.3031 - val_accuracy: 0.8812
# Epoch 12/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2602 - accuracy: 0.8986 - val_loss: 0.2825 - val_accuracy: 0.8918
# Epoch 13/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2475 - accuracy: 0.9032 - val_loss: 0.2677 - val_accuracy: 0.8999
# Epoch 14/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2468 - accuracy: 0.9020 - val_loss: 0.2846 - val_accuracy: 0.8909
# Epoch 15/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2421 - accuracy: 0.9056 - val_loss: 0.2801 - val_accuracy: 0.8949
# Epoch 16/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2378 - accuracy: 0.9066 - val_loss: 0.2508 - val_accuracy: 0.9065
# Epoch 17/35
# 1497/1497 [==============================] - 124s 82ms/step - loss: 0.2304 - accuracy: 0.9103 - val_loss: 0.3176 - val_accuracy: 0.8858
# Epoch 18/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2238 - accuracy: 0.9128 - val_loss: 0.2505 - val_accuracy: 0.9094
# Epoch 19/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2240 - accuracy: 0.9128 - val_loss: 0.2524 - val_accuracy: 0.9096
# Epoch 20/35
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.2210 - accuracy: 0.9133 - val_loss: 0.2684 - val_accuracy: 0.9050
# Epoch 21/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2189 - accuracy: 0.9155 - val_loss: 0.2570 - val_accuracy: 0.9059
# Epoch 22/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2156 - accuracy: 0.9159 - val_loss: 0.2530 - val_accuracy: 0.9063
# Epoch 23/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2117 - accuracy: 0.9174 - val_loss: 0.2480 - val_accuracy: 0.9085
# Epoch 24/35
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.2098 - accuracy: 0.9180 - val_loss: 0.2767 - val_accuracy: 0.8998
# Epoch 25/35
# 1497/1497 [==============================] - 124s 82ms/step - loss: 0.2050 - accuracy: 0.9203 - val_loss: 0.2482 - val_accuracy: 0.9106
# Epoch 26/35
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.2068 - accuracy: 0.9195 - val_loss: 0.2527 - val_accuracy: 0.9101
# Epoch 27/35
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.2036 - accuracy: 0.9222 - val_loss: 0.2456 - val_accuracy: 0.9128
# Epoch 28/35
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.2056 - accuracy: 0.9196 - val_loss: 0.2496 - val_accuracy: 0.9086
# Epoch 29/35
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.1963 - accuracy: 0.9236 - val_loss: 0.2613 - val_accuracy: 0.9074
# Epoch 30/35
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.1970 - accuracy: 0.9238 - val_loss: 0.2691 - val_accuracy: 0.9051
# Epoch 31/35
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1920 - accuracy: 0.9258 - val_loss: 0.2537 - val_accuracy: 0.9122
# Epoch 32/35
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.1950 - accuracy: 0.9240 - val_loss: 0.2464 - val_accuracy: 0.9155
# Epoch 33/35
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.1944 - accuracy: 0.9244 - val_loss: 0.3269 - val_accuracy: 0.8882
# Epoch 34/35
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1915 - accuracy: 0.9263 - val_loss: 0.2380 - val_accuracy: 0.9179
# Epoch 35/35
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.1897 - accuracy: 0.9271 - val_loss: 0.2454 - val_accuracy: 0.9121

# %%
#-------------------------------------------------------------------------------

print(cb_I03_D003.times)
final_time = 0
for time in cb_I03_D003.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D003.history['accuracy'])))
print('loss => '+ str(min(history_I03_D003.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D003.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D003.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D003.history['accuracy']
val_acc = history_I03_D003.history['val_accuracy']

loss=history_I03_D003.history['loss']
val_loss=history_I03_D003.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [140.61288690567017, 120.43704581260681, 122.3971095085144, 123.22010684013367, 121.35645747184753, 122.31632018089294, 121.34104013442993, 121.5194685459137, 121.52310991287231, 121.4620668888092, 121.20100951194763, 122.04409456253052, 123.08782386779785, 122.63059782981873, 122.0378303527832, 122.3461537361145, 123.5725257396698, 122.54287719726562, 122.84545397758484, 122.28331446647644, 122.85480165481567, 122.92342853546143, 123.01855945587158, 123.27248764038086, 123.84517884254456, 123.92823767662048, 124.23202180862427, 124.73180150985718, 124.12661576271057, 124.40030264854431, 125.23751378059387, 125.181795835495, 124.36604142189026, 125.87893795967102, 125.57481479644775]
# El entrenamiento se demoro: 4324.349832773209 segundos
# El entrenamiento se demoro: 72.07249721288682 minutos
# accuracy => 0.9270802736282349
# loss => 0.18974041938781738
# val_accuracy => 0.9179123044013977
# val_loss => 0.23798079788684845

# %% [markdown]
# ## Modelo DS002-I03-D004

# %%
#-------------------------------------------------------------------------------
from time import time
cb_I03_D004 = TimingCallback()
num_classes = 5
epochs=30

model_I03_D004 = Sequential([
  layers.Conv2D(8, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='sigmoid'),
  layers.Dense(num_classes)
])
model_I03_D004.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D004.summary()


history_I03_D004 = model_I03_D004.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D004]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/30
# 1497/1497 [==============================] - 141s 83ms/step - loss: 1.3436 - accuracy: 0.4440 - val_loss: 1.2611 - val_accuracy: 0.4957
# Epoch 2/30
# 1497/1497 [==============================] - 123s 82ms/step - loss: 1.0937 - accuracy: 0.5640 - val_loss: 0.9692 - val_accuracy: 0.5979
# Epoch 3/30
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.9098 - accuracy: 0.6148 - val_loss: 0.8363 - val_accuracy: 0.6330
# Epoch 4/30
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.8150 - accuracy: 0.6445 - val_loss: 0.7955 - val_accuracy: 0.6595
# Epoch 5/30
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.7734 - accuracy: 0.6761 - val_loss: 0.7296 - val_accuracy: 0.7091
# Epoch 6/30
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.7319 - accuracy: 0.7025 - val_loss: 0.6927 - val_accuracy: 0.7262
# Epoch 7/30
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.6982 - accuracy: 0.7197 - val_loss: 0.6845 - val_accuracy: 0.7273
# Epoch 8/30
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.6631 - accuracy: 0.7371 - val_loss: 0.6910 - val_accuracy: 0.7297
# Epoch 9/30
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.6298 - accuracy: 0.7544 - val_loss: 0.5899 - val_accuracy: 0.7663
# Epoch 10/30
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.6043 - accuracy: 0.7644 - val_loss: 0.6688 - val_accuracy: 0.7349
# Epoch 11/30
# 1497/1497 [==============================] - 128s 85ms/step - loss: 0.5793 - accuracy: 0.7767 - val_loss: 0.5715 - val_accuracy: 0.7707
# Epoch 12/30
# 1497/1497 [==============================] - 128s 85ms/step - loss: 0.5614 - accuracy: 0.7811 - val_loss: 0.6668 - val_accuracy: 0.7385
# Epoch 13/30
# 1497/1497 [==============================] - 128s 85ms/step - loss: 0.5445 - accuracy: 0.7917 - val_loss: 0.5556 - val_accuracy: 0.7947
# Epoch 14/30
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.5278 - accuracy: 0.7972 - val_loss: 0.5327 - val_accuracy: 0.7970
# Epoch 15/30
# 1497/1497 [==============================] - 124s 82ms/step - loss: 0.5145 - accuracy: 0.8030 - val_loss: 0.5497 - val_accuracy: 0.7849
# Epoch 16/30
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.5075 - accuracy: 0.8061 - val_loss: 0.4989 - val_accuracy: 0.8132
# Epoch 17/30
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.4948 - accuracy: 0.8112 - val_loss: 0.4979 - val_accuracy: 0.8111
# Epoch 18/30
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.4801 - accuracy: 0.8166 - val_loss: 0.4884 - val_accuracy: 0.8128
# Epoch 19/30
# 1497/1497 [==============================] - 129s 86ms/step - loss: 0.4638 - accuracy: 0.8245 - val_loss: 0.4606 - val_accuracy: 0.8287
# Epoch 20/30
# 1497/1497 [==============================] - 129s 86ms/step - loss: 0.4401 - accuracy: 0.8349 - val_loss: 0.4438 - val_accuracy: 0.8365
# Epoch 21/30
# 1497/1497 [==============================] - 129s 86ms/step - loss: 0.4275 - accuracy: 0.8397 - val_loss: 0.4195 - val_accuracy: 0.8486
# Epoch 22/30
# 1497/1497 [==============================] - 128s 85ms/step - loss: 0.4126 - accuracy: 0.8435 - val_loss: 0.3955 - val_accuracy: 0.8574
# Epoch 23/30
# 1497/1497 [==============================] - 129s 86ms/step - loss: 0.3871 - accuracy: 0.8547 - val_loss: 0.3796 - val_accuracy: 0.8608
# Epoch 24/30
# 1497/1497 [==============================] - 128s 85ms/step - loss: 0.3668 - accuracy: 0.8615 - val_loss: 0.3767 - val_accuracy: 0.8643
# Epoch 25/30
# 1497/1497 [==============================] - 127s 85ms/step - loss: 0.3480 - accuracy: 0.8697 - val_loss: 0.3536 - val_accuracy: 0.8669
# Epoch 26/30
# 1497/1497 [==============================] - 125s 83ms/step - loss: 0.3366 - accuracy: 0.8757 - val_loss: 0.3480 - val_accuracy: 0.8722
# Epoch 27/30
# 1497/1497 [==============================] - 121s 81ms/step - loss: 0.3229 - accuracy: 0.8808 - val_loss: 0.3219 - val_accuracy: 0.8854
# Epoch 28/30
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.3155 - accuracy: 0.8827 - val_loss: 0.3336 - val_accuracy: 0.8777
# Epoch 29/30
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.3051 - accuracy: 0.8868 - val_loss: 0.4286 - val_accuracy: 0.8392
# Epoch 30/30
# 1497/1497 [==============================] - 126s 84ms/step - loss: 0.2920 - accuracy: 0.8910 - val_loss: 0.2905 - val_accuracy: 0.8950

# %%
#-------------------------------------------------------------------------------

print(cb_I03_D004.times)
final_time = 0
for time in cb_I03_D004.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D004.history['accuracy'])))
print('loss => '+ str(min(history_I03_D004.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D004.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D004.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D004.history['accuracy']
val_acc = history_I03_D004.history['val_accuracy']

loss=history_I03_D004.history['loss']
val_loss=history_I03_D004.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [141.20116424560547, 123.12764644622803, 122.65060186386108, 124.69945812225342, 123.21423816680908, 123.30779600143433, 122.36584115028381, 121.58658957481384, 125.38966846466064, 126.44094133377075, 127.99348878860474, 128.02192544937134, 128.14940667152405, 122.8721854686737, 123.87803983688354, 124.80114412307739, 125.91478300094604, 126.25413465499878, 128.69677662849426, 129.44077587127686, 128.75530886650085, 127.58511877059937, 129.45748901367188, 128.33702540397644, 127.03205442428589, 124.9958803653717, 121.10575938224792, 121.8592574596405, 122.72194647789001, 125.9239399433136]
# El entrenamiento se demoro: 3777.7803859710693 segundos
# El entrenamiento se demoro: 62.96300643285115 minutos
# accuracy => 0.8910066485404968
# loss => 0.29203471541404724
# val_accuracy => 0.8950313329696655
# val_loss => 0.2904820740222931

# %% [markdown]
# ## Modelo DS002-I03-D005

# %%
from tensorflow.keras import regularizers
from time import time
#-------------------------------------------------------------------------------
cbI03_D005 = TimingCallback()
num_classes = 5

modelI03_D005 = Sequential([
  # layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(8, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes)
])
modelI03_D005.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# modelI03_D005.summary()

epochs=20
historyI03_D005 = modelI03_D005.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cbI03_D005]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 749/749 [==============================] - 113s 149ms/step - loss: 1.9113 - accuracy: 0.6510 - val_loss: 0.6294 - val_accuracy: 0.7627
# Epoch 2/20
# 749/749 [==============================] - 113s 149ms/step - loss: 0.5448 - accuracy: 0.8025 - val_loss: 0.4733 - val_accuracy: 0.8330
# Epoch 3/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.4180 - accuracy: 0.8578 - val_loss: 0.4107 - val_accuracy: 0.8634
# Epoch 4/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.3410 - accuracy: 0.8877 - val_loss: 0.3541 - val_accuracy: 0.8858
# Epoch 5/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.2978 - accuracy: 0.9015 - val_loss: 0.4013 - val_accuracy: 0.8676
# Epoch 6/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.2662 - accuracy: 0.9119 - val_loss: 0.3070 - val_accuracy: 0.9026
# Epoch 7/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.2397 - accuracy: 0.9219 - val_loss: 0.3054 - val_accuracy: 0.9081
# Epoch 8/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.2108 - accuracy: 0.9319 - val_loss: 0.3781 - val_accuracy: 0.8910
# Epoch 9/20
# 749/749 [==============================] - 113s 149ms/step - loss: 0.2015 - accuracy: 0.9364 - val_loss: 0.3046 - val_accuracy: 0.9081
# Epoch 10/20
# 749/749 [==============================] - 113s 149ms/step - loss: 0.1823 - accuracy: 0.9430 - val_loss: 0.3128 - val_accuracy: 0.9074
# Epoch 11/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.1649 - accuracy: 0.9489 - val_loss: 0.3285 - val_accuracy: 0.9094
# Epoch 12/20
# 749/749 [==============================] - 113s 149ms/step - loss: 0.1609 - accuracy: 0.9513 - val_loss: 0.3157 - val_accuracy: 0.9132
# Epoch 13/20
# 749/749 [==============================] - 111s 148ms/step - loss: 0.1476 - accuracy: 0.9565 - val_loss: 0.3465 - val_accuracy: 0.9106
# Epoch 14/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.1503 - accuracy: 0.9552 - val_loss: 0.3680 - val_accuracy: 0.9012
# Epoch 15/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.1357 - accuracy: 0.9623 - val_loss: 0.3324 - val_accuracy: 0.9223
# Epoch 16/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.1293 - accuracy: 0.9648 - val_loss: 0.3561 - val_accuracy: 0.9166
# Epoch 17/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.1104 - accuracy: 0.9705 - val_loss: 0.3830 - val_accuracy: 0.9143
# Epoch 18/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.1078 - accuracy: 0.9720 - val_loss: 0.4454 - val_accuracy: 0.9108
# Epoch 19/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.0987 - accuracy: 0.9751 - val_loss: 0.3396 - val_accuracy: 0.9263
# Epoch 20/20
# 749/749 [==============================] - 112s 149ms/step - loss: 0.1021 - accuracy: 0.9749 - val_loss: 0.4366 - val_accuracy: 0.9142

# %%
#-------------------------------------------------------------------------------
print(cbI03_D005.times)
final_time = 0
for time in cbI03_D005.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(historyI03_D005.history['accuracy'])))
print('loss => '+ str(min(historyI03_D005.history['loss'])))
print('val_accuracy => '+ str(max(historyI03_D005.history['val_accuracy'])))
print('val_loss => '+ str(min(historyI03_D005.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = historyI03_D005.history['accuracy']
val_acc = historyI03_D005.history['val_accuracy']

loss=historyI03_D005.history['loss']
val_loss=historyI03_D005.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [113.12719392776489, 112.65423583984375, 111.70099639892578, 112.50060510635376, 113.00310564041138, 111.89015293121338, 112.3880729675293, 112.15271615982056, 112.57184839248657, 112.52630710601807, 112.39203882217407, 112.65004277229309, 111.488276720047, 111.2265362739563, 111.81472992897034, 112.19080400466919, 112.0470826625824, 112.32808780670166, 111.7339563369751, 112.44153380393982]
# El entrenamiento se demoro: 2244.8283236026764 segundos
# El entrenamiento se demoro: 37.41380539337794 minutos
# accuracy => 0.9751367568969727
# loss => 0.0987192839384079
# val_accuracy => 0.9263465404510498
# val_loss => 0.30464038252830505

# %% [markdown]
# ## Modelo DS002-I03-D006

# %%
from tensorflow.keras import regularizers
from time import time
#-------------------------------------------------------------------------------
cb_I03_D006 = TimingCallback()
num_classes = 10

model_I03_D006 = Sequential([
  # layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D (16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes)
])
model_I03_D006.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D006.summary()

epochs=20
history_I03_D006 = model_I03_D006.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D006]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 749/749 [==============================] - 114s 151ms/step - loss: 3.2551 - accuracy: 0.6680 - val_loss: 0.8597 - val_accuracy: 0.7262
# Epoch 2/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.7519 - accuracy: 0.7756 - val_loss: 0.7721 - val_accuracy: 0.7702
# Epoch 3/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.6623 - accuracy: 0.8145 - val_loss: 0.6857 - val_accuracy: 0.8110
# Epoch 4/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.9201 - accuracy: 0.7322 - val_loss: 0.8192 - val_accuracy: 0.7609
# Epoch 5/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.7144 - accuracy: 0.7966 - val_loss: 0.7072 - val_accuracy: 0.7958
# Epoch 6/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.6258 - accuracy: 0.8276 - val_loss: 0.6448 - val_accuracy: 0.8175
# Epoch 7/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.5661 - accuracy: 0.8535 - val_loss: 0.6528 - val_accuracy: 0.8294
# Epoch 8/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.5115 - accuracy: 0.8728 - val_loss: 0.6372 - val_accuracy: 0.8396
# Epoch 9/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.4781 - accuracy: 0.8895 - val_loss: 0.6619 - val_accuracy: 0.8248
# Epoch 10/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.4358 - accuracy: 0.9048 - val_loss: 0.5532 - val_accuracy: 0.8714
# Epoch 11/20
# 749/749 [==============================] - 114s 150ms/step - loss: 0.3973 - accuracy: 0.9186 - val_loss: 0.5586 - val_accuracy: 0.8744
# Epoch 12/20
# 749/749 [==============================] - 115s 152ms/step - loss: 0.3819 - accuracy: 0.9246 - val_loss: 0.5674 - val_accuracy: 0.8766
# Epoch 13/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.4145 - accuracy: 0.9223 - val_loss: 0.5812 - val_accuracy: 0.8772
# Epoch 14/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.3492 - accuracy: 0.9398 - val_loss: 0.5837 - val_accuracy: 0.8753
# Epoch 15/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.3340 - accuracy: 0.9424 - val_loss: 0.5444 - val_accuracy: 0.8894
# Epoch 16/20
# 749/749 [==============================] - 116s 153ms/step - loss: 0.3342 - accuracy: 0.9424 - val_loss: 0.5404 - val_accuracy: 0.8893
# Epoch 17/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.3862 - accuracy: 0.9382 - val_loss: 0.6765 - val_accuracy: 0.8653
# Epoch 18/20
# 749/749 [==============================] - 116s 154ms/step - loss: 0.3728 - accuracy: 0.9433 - val_loss: 0.5506 - val_accuracy: 0.8814
# Epoch 19/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.3147 - accuracy: 0.9528 - val_loss: 0.5192 - val_accuracy: 0.9004
# Epoch 20/20
# 749/749 [==============================] - 115s 153ms/step - loss: 0.3144 - accuracy: 0.9524 - val_loss: 0.5420 - val_accuracy: 0.8985

# %%
#-------------------------------------------------------------------------------

print(cb_I03_D006.times)
final_time = 0
for time in cb_I03_D006.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D006.history['accuracy'])))
print('loss => '+ str(min(history_I03_D006.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D006.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D006.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D006.history['accuracy']
val_acc = history_I03_D006.history['val_accuracy']

loss=history_I03_D006.history['loss']
val_loss=history_I03_D006.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [114.26936650276184, 113.32579731941223, 113.85824060440063, 113.12198424339294, 112.96435451507568, 113.64170289039612, 113.15320587158203, 114.01567387580872, 113.99199390411377, 113.74753260612488, 113.56993055343628, 114.95851063728333, 113.87241649627686, 113.44769191741943, 113.8695182800293, 115.61616110801697, 114.0379638671875, 116.05242991447449, 114.27857184410095, 115.1219801902771]
# El entrenamiento se demoro: 2280.915027141571 segundos
# El entrenamiento se demoro: 38.01525045235952 minutos
# accuracy => 0.952757716178894
# loss => 0.31438109278678894
# val_accuracy => 0.9003757834434509
# val_loss => 0.5191941857337952

# %% [markdown]
# ## Modelo DS002-I03-D007

# %%
from tensorflow.keras import regularizers
from time import time
#-------------------------------------------------------------------------------
cb_I03_D007 = TimingCallback()
num_classes = 5
epochs=20

model_I03_D007 = Sequential([
  layers.Conv2D(8, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes)
])
model_I03_D007.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D007.summary()


history_I03_D007 = model_I03_D007.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D007]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 749/749 [==============================] - 112s 148ms/step - loss: 5.9403 - accuracy: 0.5590 - val_loss: 0.9222 - val_accuracy: 0.6393
# Epoch 2/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.8745 - accuracy: 0.6675 - val_loss: 0.8444 - val_accuracy: 0.6764
# Epoch 3/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.7341 - accuracy: 0.7220 - val_loss: 0.7651 - val_accuracy: 0.7146
# Epoch 4/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.6485 - accuracy: 0.7558 - val_loss: 0.7752 - val_accuracy: 0.7235
# Epoch 5/20
# 749/749 [==============================] - 111s 148ms/step - loss: 0.6105 - accuracy: 0.7705 - val_loss: 0.7642 - val_accuracy: 0.7214
# Epoch 6/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.5913 - accuracy: 0.7811 - val_loss: 0.7123 - val_accuracy: 0.7451
# Epoch 7/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.5643 - accuracy: 0.7933 - val_loss: 0.7082 - val_accuracy: 0.7451
# Epoch 8/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.5573 - accuracy: 0.8017 - val_loss: 0.6926 - val_accuracy: 0.7569
# Epoch 9/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.5438 - accuracy: 0.8085 - val_loss: 0.7222 - val_accuracy: 0.7594
# Epoch 10/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.5284 - accuracy: 0.8204 - val_loss: 0.7155 - val_accuracy: 0.7658
# Epoch 11/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.5136 - accuracy: 0.8315 - val_loss: 0.7411 - val_accuracy: 0.7687
# Epoch 12/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.5066 - accuracy: 0.8394 - val_loss: 0.7452 - val_accuracy: 0.7719
# Epoch 13/20
# 749/749 [==============================] - 111s 148ms/step - loss: 0.4913 - accuracy: 0.8550 - val_loss: 0.6643 - val_accuracy: 0.8045
# Epoch 14/20
# 749/749 [==============================] - 111s 148ms/step - loss: 0.4596 - accuracy: 0.8718 - val_loss: 0.7005 - val_accuracy: 0.7972
# Epoch 15/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.4296 - accuracy: 0.8895 - val_loss: 0.6060 - val_accuracy: 0.8471
# Epoch 16/20
# 749/749 [==============================] - 111s 148ms/step - loss: 0.3853 - accuracy: 0.9103 - val_loss: 0.6062 - val_accuracy: 0.8495
# Epoch 17/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.3682 - accuracy: 0.9193 - val_loss: 0.5849 - val_accuracy: 0.8615
# Epoch 18/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.3489 - accuracy: 0.9273 - val_loss: 0.6012 - val_accuracy: 0.8594
# Epoch 19/20
# 749/749 [==============================] - 112s 148ms/step - loss: 0.3607 - accuracy: 0.9252 - val_loss: 0.6126 - val_accuracy: 0.8522
# Epoch 20/20
# 749/749 [==============================] - 111s 147ms/step - loss: 0.3400 - accuracy: 0.9338 - val_loss: 0.5993 - val_accuracy: 0.8645

# %%
#-------------------------------------------------------------------------------

print(cb_I03_D007.times)
final_time = 0
for time in cb_I03_D007.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D007.history['accuracy'])))
print('loss => '+ str(min(history_I03_D007.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D007.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D007.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D007.history['accuracy']
val_acc = history_I03_D007.history['val_accuracy']

loss=history_I03_D007.history['loss']
val_loss=history_I03_D007.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [112.35335111618042, 111.26008081436157, 111.2876079082489, 110.78749227523804, 111.36792993545532, 110.76215291023254, 110.9896445274353, 110.81444764137268, 110.84769630432129, 111.6601231098175, 111.02625775337219, 111.21522808074951, 111.3414568901062, 111.45664405822754, 111.13966608047485, 111.3648898601532, 111.58373498916626, 111.1319227218628, 111.77062487602234, 110.90761375427246]
# El entrenamiento se demoro: 2225.068565607071 segundos
# El entrenamiento se demoro: 37.08447609345118 minutos
# accuracy => 0.9337605834007263
# loss => 0.3399716019630432
# val_accuracy => 0.8644676208496094
# val_loss => 0.5849406123161316

# %% [markdown]
# ## Modelo DS002-I03-D008

# %%
from tensorflow.keras import regularizers
from time import time
#-------------------------------------------------------------------------------
cb_I03_D008 = TimingCallback()
num_classes = 5

model_I03_D008 = Sequential([
  # layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(8, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.0001)),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.0001)),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(0.0001)),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.0001)),
  layers.Dense(num_classes)
])
model_I03_D008.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I03_D008.summary()

epochs=20
history_I03_D008 = model_I03_D008.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I03_D008]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 749/749 [==============================] - 114s 150ms/step - loss: 2.1832 - accuracy: 0.6930 - val_loss: 0.5549 - val_accuracy: 0.7687
# Epoch 2/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.4793 - accuracy: 0.8063 - val_loss: 0.4705 - val_accuracy: 0.8140
# Epoch 3/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.3853 - accuracy: 0.8487 - val_loss: 0.4473 - val_accuracy: 0.8359
# Epoch 4/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.3305 - accuracy: 0.8788 - val_loss: 0.3948 - val_accuracy: 0.8668
# Epoch 5/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.2766 - accuracy: 0.9046 - val_loss: 0.4232 - val_accuracy: 0.8688
# Epoch 6/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.2281 - accuracy: 0.9261 - val_loss: 0.3590 - val_accuracy: 0.8965
# Epoch 7/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.2159 - accuracy: 0.9339 - val_loss: 0.4262 - val_accuracy: 0.8863
# Epoch 8/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1812 - accuracy: 0.9469 - val_loss: 0.3611 - val_accuracy: 0.9070
# Epoch 9/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.1640 - accuracy: 0.9561 - val_loss: 0.3680 - val_accuracy: 0.9145
# Epoch 10/20
# 749/749 [==============================] - 114s 150ms/step - loss: 0.1619 - accuracy: 0.9582 - val_loss: 0.4175 - val_accuracy: 0.9035
# Epoch 11/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1482 - accuracy: 0.9640 - val_loss: 0.4723 - val_accuracy: 0.8954
# Epoch 12/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.1475 - accuracy: 0.9650 - val_loss: 0.3618 - val_accuracy: 0.9163
# Epoch 13/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1400 - accuracy: 0.9683 - val_loss: 0.3849 - val_accuracy: 0.9183
# Epoch 14/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1326 - accuracy: 0.9726 - val_loss: 0.4170 - val_accuracy: 0.9191
# Epoch 15/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1332 - accuracy: 0.9732 - val_loss: 0.4406 - val_accuracy: 0.9113
# Epoch 16/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1624 - accuracy: 0.9654 - val_loss: 0.4277 - val_accuracy: 0.9157
# Epoch 17/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.1166 - accuracy: 0.9805 - val_loss: 0.5111 - val_accuracy: 0.9030
# Epoch 18/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1296 - accuracy: 0.9764 - val_loss: 0.4278 - val_accuracy: 0.9188
# Epoch 19/20
# 749/749 [==============================] - 114s 151ms/step - loss: 0.1301 - accuracy: 0.9773 - val_loss: 0.4052 - val_accuracy: 0.9228
# Epoch 20/20
# 749/749 [==============================] - 113s 150ms/step - loss: 0.1263 - accuracy: 0.9794 - val_loss: 0.5419 - val_accuracy: 0.9066

# %%
#-------------------------------------------------------------------------------
print(cb_I03_D008.times)
final_time = 0
for time in cb_I03_D008.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I03_D008.history['accuracy'])))
print('loss => '+ str(min(history_I03_D008.history['loss'])))
print('val_accuracy => '+ str(max(history_I03_D008.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I03_D008.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I03_D008.history['accuracy']
val_acc = history_I03_D008.history['val_accuracy']

loss=history_I03_D008.history['loss']
val_loss=history_I03_D008.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [113.81656908988953, 114.2742805480957, 113.43481040000916, 114.1779670715332, 113.72886490821838, 113.1715795993805, 113.6744339466095, 113.2036645412445, 113.62428283691406, 113.51068592071533, 113.21020293235779, 113.89488458633423, 113.38997030258179, 113.07827568054199, 113.20237755775452, 113.37986898422241, 113.59625744819641, 113.13308453559875, 114.07154631614685, 113.35551381111145]
# El entrenamiento se demoro: 2270.929121017456 segundos
# El entrenamiento se demoro: 37.848818683624266 minutos
# accuracy => 0.9805227518081665
# loss => 0.11660191416740417
# val_accuracy => 0.9227557182312012
# val_loss => 0.35899096727371216
