# %% [markdown]
# <a href="https://colab.research.google.com/github/Sisterno/ML_RedesNeuronales/blob/master/Modelo_entrenamiento__IT02_D001-%3ED006_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from time import time
import pathlib

path_img_leucocitos = "/content/drive/MyDrive/ML/04-dataset-preprocesado-fusion";
pathlib_img_leucocitos=pathlib.Path(path_img_leucocitos)

from google.colab import drive
drive.mount('/content/drive')

# batch_size = 32
batch_size = 512
img_height = 180
img_width = 180

#-------------------------------------------------------------------------------
# def obtenerTimer():
#   class TimingCallback(keras.callbacks.Callback):
#     def on_train_begin(self, logs={}):
#         self.times = []
#     def on_epoch_begin(self, batch, logs={}):
#         self.epoch_time_start = time()
#     def on_epoch_end(self, batch, logs={}):
#         self.times.append(time() - self.epoch_time_start)
#   cb = TimingCallback()
#   return cb

class TimingCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []
    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time()
    def on_epoch_end(self, batch, logs={}):
        self.times.append(time() - self.epoch_time_start)
#-------------------------------------------------------------------------------

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  path_img_leucocitos,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  path_img_leucocitos,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)

AUTOTUNE = tf.data.AUTOTUNE

# train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
# val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 59877 files belonging to 5 classes.
# Using 47902 files for training.
# Found 59877 files belonging to 5 classes.
# Using 11975 files for validation.

# %% [markdown]
# ## Modelo DS002-I02-D001

# %%
#-------------------------------------------------------------------------------

cb_I02_D001 = TimingCallback()
num_classes = 5
epochs=20

model_I02_D001 = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(16, activation='relu'),
  layers.Dense(num_classes)
])
model_I02_D001.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


history_I02_D001 = model_I02_D001.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I02_D001]
)
model_I02_D001.summary()

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 375/375 [==============================] - 6479s 17s/step - loss: 1.0541 - accuracy: 0.5611 - val_loss: 0.7764 - val_accuracy: 0.6571
# Epoch 2/20
# 375/375 [==============================] - 131s 345ms/step - loss: 0.6959 - accuracy: 0.7119 - val_loss: 0.6611 - val_accuracy: 0.7271
# Epoch 3/20
# 375/375 [==============================] - 131s 344ms/step - loss: 0.5813 - accuracy: 0.7631 - val_loss: 0.5967 - val_accuracy: 0.7608
# Epoch 4/20
# 375/375 [==============================] - 130s 342ms/step - loss: 0.5249 - accuracy: 0.7844 - val_loss: 0.5743 - val_accuracy: 0.7704
# Epoch 5/20
# 375/375 [==============================] - 129s 338ms/step - loss: 0.4796 - accuracy: 0.8029 - val_loss: 0.5014 - val_accuracy: 0.7982
# Epoch 6/20
# 375/375 [==============================] - 131s 345ms/step - loss: 0.4380 - accuracy: 0.8200 - val_loss: 0.4903 - val_accuracy: 0.8018
# Epoch 7/20
# 375/375 [==============================] - 131s 343ms/step - loss: 0.4056 - accuracy: 0.8337 - val_loss: 0.4960 - val_accuracy: 0.8049
# Epoch 8/20
# 375/375 [==============================] - 130s 342ms/step - loss: 0.3824 - accuracy: 0.8432 - val_loss: 0.4803 - val_accuracy: 0.8099
# Epoch 9/20
# 375/375 [==============================] - 131s 343ms/step - loss: 0.3654 - accuracy: 0.8509 - val_loss: 0.4673 - val_accuracy: 0.8180
# Epoch 10/20
# 375/375 [==============================] - 130s 343ms/step - loss: 0.3491 - accuracy: 0.8580 - val_loss: 0.4501 - val_accuracy: 0.8256
# Epoch 11/20
# 375/375 [==============================] - 131s 343ms/step - loss: 0.3286 - accuracy: 0.8648 - val_loss: 0.4642 - val_accuracy: 0.8301
# Epoch 12/20
# 375/375 [==============================] - 131s 344ms/step - loss: 0.3147 - accuracy: 0.8739 - val_loss: 0.4493 - val_accuracy: 0.8329
# Epoch 13/20
# 375/375 [==============================] - 131s 344ms/step - loss: 0.3025 - accuracy: 0.8785 - val_loss: 0.4429 - val_accuracy: 0.8357
# Epoch 14/20
# 375/375 [==============================] - 131s 345ms/step - loss: 0.2903 - accuracy: 0.8851 - val_loss: 0.4530 - val_accuracy: 0.8367
# Epoch 15/20
# 375/375 [==============================] - 131s 343ms/step - loss: 0.2752 - accuracy: 0.8919 - val_loss: 0.4291 - val_accuracy: 0.8457
# Epoch 16/20
# 375/375 [==============================] - 131s 344ms/step - loss: 0.2572 - accuracy: 0.8976 - val_loss: 0.4574 - val_accuracy: 0.8443
# Epoch 17/20
# 375/375 [==============================] - 130s 342ms/step - loss: 0.2504 - accuracy: 0.8995 - val_loss: 0.4761 - val_accuracy: 0.8437
# Epoch 18/20
# 375/375 [==============================] - 131s 343ms/step - loss: 0.2459 - accuracy: 0.9039 - val_loss: 0.4644 - val_accuracy: 0.8484
# Epoch 19/20
# 375/375 [==============================] - 130s 340ms/step - loss: 0.2328 - accuracy: 0.9085 - val_loss: 0.4489 - val_accuracy: 0.8545
# Epoch 20/20
# 375/375 [==============================] - 130s 342ms/step - loss: 0.2249 - accuracy: 0.9122 - val_loss: 0.4934 - val_accuracy: 0.8413
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 180, 180, 4)       112
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 4)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 8)         296
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 8)         584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 8)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3872)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                61968
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 85
# =================================================================
# Total params: 63,045
# Trainable params: 63,045
# Non-trainable params: 0
# _________________________________________________________________

# %%
#-------------------------------------------------------------------------------

print(cb_I02_D001.times)
final_time = 0
for time in cb_I02_D001.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I02_D001.history['accuracy'])))
print('loss => '+ str(min(history_I02_D001.history['loss'])))
print('val_accuracy => '+ str(max(history_I02_D001.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I02_D001.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I02_D001.history['accuracy']
val_acc = history_I02_D001.history['val_accuracy']

loss=history_I02_D001.history['loss']
val_loss=history_I02_D001.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [6479.051737308502, 131.32184481620789, 131.03176856040955, 130.28166031837463, 128.90106844902039, 131.1424264907837, 130.6346833705902, 130.33430790901184, 130.64835214614868, 130.4586570262909, 130.70475840568542, 131.16691732406616, 131.18976044654846, 131.23889207839966, 130.58212232589722, 131.0295000076294, 130.20770502090454, 130.53413796424866, 129.64573431015015, 130.3091812133789]
# El entrenamiento se demoro: 8960.415215492249 segundos
# El entrenamiento se demoro: 149.34025359153748 minutos
# accuracy => 0.9121748805046082
# loss => 0.22488969564437866
# val_accuracy => 0.8545302748680115
# val_loss => 0.4290696382522583

# %% [markdown]
# ## Modelo DS002-I02-D002

# %%
from time import time
class TimingCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []
    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time()
    def on_epoch_end(self, batch, logs={}):
        self.times.append(time() - self.epoch_time_start)

# %%
#-------------------------------------------------------------------------------

cb_I02_D002 = TimingCallback()
num_classes = 5
epochs=20

model_I02_D002 = Sequential([
  layers.Conv2D(8, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='sigmoid'),
  layers.Dense(num_classes)
])
model_I02_D002.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I02_D002.summary()


history_I02_D002 = model_I02_D002.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I02_D002]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 94/94 [==============================] - 135s 1s/step - loss: 1.6421 - accuracy: 0.3252 - val_loss: 1.5650 - val_accuracy: 0.3240
# Epoch 2/20
# 94/94 [==============================] - 131s 1s/step - loss: 1.5556 - accuracy: 0.3270 - val_loss: 1.5455 - val_accuracy: 0.3240
# Epoch 3/20
# 94/94 [==============================] - 130s 1s/step - loss: 1.5111 - accuracy: 0.4148 - val_loss: 1.4935 - val_accuracy: 0.4335
# Epoch 4/20
# 94/94 [==============================] - 130s 1s/step - loss: 1.4351 - accuracy: 0.4365 - val_loss: 1.3963 - val_accuracy: 0.4379
# Epoch 5/20
# 94/94 [==============================] - 129s 1s/step - loss: 1.3915 - accuracy: 0.4421 - val_loss: 1.3722 - val_accuracy: 0.4446
# Epoch 6/20
# 94/94 [==============================] - 129s 1s/step - loss: 1.3545 - accuracy: 0.4517 - val_loss: 1.3142 - val_accuracy: 0.4769
# Epoch 7/20
# 94/94 [==============================] - 128s 1s/step - loss: 1.2548 - accuracy: 0.5084 - val_loss: 1.1860 - val_accuracy: 0.5236
# Epoch 8/20
# 94/94 [==============================] - 126s 1s/step - loss: 1.1612 - accuracy: 0.5440 - val_loss: 1.1326 - val_accuracy: 0.5614
# Epoch 9/20
# 94/94 [==============================] - 127s 1s/step - loss: 1.1197 - accuracy: 0.5736 - val_loss: 1.1179 - val_accuracy: 0.5738
# Epoch 10/20
# 94/94 [==============================] - 125s 1s/step - loss: 1.0872 - accuracy: 0.5897 - val_loss: 1.0893 - val_accuracy: 0.5919
# Epoch 11/20
# 94/94 [==============================] - 123s 1s/step - loss: 1.0581 - accuracy: 0.6123 - val_loss: 1.0397 - val_accuracy: 0.6341
# Epoch 12/20
# 94/94 [==============================] - 127s 1s/step - loss: 1.0400 - accuracy: 0.6339 - val_loss: 1.0138 - val_accuracy: 0.6483
# Epoch 13/20
# 94/94 [==============================] - 127s 1s/step - loss: 1.0074 - accuracy: 0.6506 - val_loss: 0.9824 - val_accuracy: 0.6555
# Epoch 14/20
# 94/94 [==============================] - 127s 1s/step - loss: 0.9691 - accuracy: 0.6668 - val_loss: 0.9581 - val_accuracy: 0.6769
# Epoch 15/20
# 94/94 [==============================] - 130s 1s/step - loss: 0.9206 - accuracy: 0.6841 - val_loss: 0.9102 - val_accuracy: 0.6895
# Epoch 16/20
# 94/94 [==============================] - 124s 1s/step - loss: 0.8843 - accuracy: 0.6941 - val_loss: 0.8630 - val_accuracy: 0.7031
# Epoch 17/20
# 94/94 [==============================] - 125s 1s/step - loss: 0.8574 - accuracy: 0.7001 - val_loss: 0.8366 - val_accuracy: 0.7081
# Epoch 18/20
# 94/94 [==============================] - 123s 1s/step - loss: 0.8329 - accuracy: 0.7058 - val_loss: 0.8184 - val_accuracy: 0.7161
# Epoch 19/20
# 94/94 [==============================] - 124s 1s/step - loss: 0.8098 - accuracy: 0.7128 - val_loss: 0.8035 - val_accuracy: 0.7137
# Epoch 20/20
# 94/94 [==============================] - 123s 1s/step - loss: 0.7971 - accuracy: 0.7115 - val_loss: 0.7820 - val_accuracy: 0.7182

# %%
#-------------------------------------------------------------------------------

print(cb_I02_D002.times)
final_time = 0
for time in cb_I02_D002.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I02_D002.history['accuracy'])))
print('loss => '+ str(min(history_I02_D002.history['loss'])))
print('val_accuracy => '+ str(max(history_I02_D002.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I02_D002.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I02_D002.history['accuracy']
val_acc = history_I02_D002.history['val_accuracy']

loss=history_I02_D002.history['loss']
val_loss=history_I02_D002.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [134.89904618263245, 131.2036919593811, 130.2089991569519, 129.53182435035706, 128.69750547409058, 128.7528781890869, 127.82669425010681, 125.51134085655212, 126.8277599811554, 124.6426613330841, 123.4942216873169, 127.10945677757263, 126.88057279586792, 126.7645537853241, 130.1834442615509, 124.43920230865479, 124.60406970977783, 123.06736207008362, 123.74948787689209, 123.38024878501892]
# El entrenamiento se demoro: 2541.775021791458 segundos
# El entrenamiento se demoro: 42.362917029857634 minutos
# accuracy => 0.7128095030784607
# loss => 0.7971164584159851
# val_accuracy => 0.7181628346443176
# val_loss => 0.7820010185241699

# %% [markdown]
# ## Modelo DS002-I02-D003

# %%
#-------------------------------------------------------------------------------

cb_I02_D003 = TimingCallback()
num_classes = 5
epochs=15

model_I02_D003 = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(16, activation='relu'),
  layers.Dense(num_classes)
])
model_I02_D003.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I02_D003.summary()


history_I02_D003 = model_I02_D003.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I02_D003]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/15
# 375/375 [==============================] - 135s 353ms/step - loss: 1.4262 - accuracy: 0.5078 - val_loss: 0.8048 - val_accuracy: 0.6794
# Epoch 2/15
# 375/375 [==============================] - 135s 353ms/step - loss: 0.7181 - accuracy: 0.7054 - val_loss: 0.6724 - val_accuracy: 0.7223
# Epoch 3/15
# 375/375 [==============================] - 134s 351ms/step - loss: 0.6195 - accuracy: 0.7431 - val_loss: 0.5906 - val_accuracy: 0.7592
# Epoch 4/15
# 375/375 [==============================] - 133s 350ms/step - loss: 0.5699 - accuracy: 0.7637 - val_loss: 0.5631 - val_accuracy: 0.7750
# Epoch 5/15
# 375/375 [==============================] - 133s 350ms/step - loss: 0.5368 - accuracy: 0.7770 - val_loss: 0.5820 - val_accuracy: 0.7643
# Epoch 6/15
# 375/375 [==============================] - 135s 354ms/step - loss: 0.5073 - accuracy: 0.7893 - val_loss: 0.5644 - val_accuracy: 0.7811
# Epoch 7/15
# 375/375 [==============================] - 131s 344ms/step - loss: 0.4907 - accuracy: 0.7974 - val_loss: 0.5225 - val_accuracy: 0.7852
# Epoch 8/15
# 375/375 [==============================] - 134s 352ms/step - loss: 0.4603 - accuracy: 0.8099 - val_loss: 0.4576 - val_accuracy: 0.8108
# Epoch 9/15
# 375/375 [==============================] - 136s 356ms/step - loss: 0.4409 - accuracy: 0.8191 - val_loss: 0.4735 - val_accuracy: 0.8034
# Epoch 10/15
# 375/375 [==============================] - 136s 356ms/step - loss: 0.4240 - accuracy: 0.8284 - val_loss: 0.4597 - val_accuracy: 0.8139
# Epoch 11/15
# 375/375 [==============================] - 135s 355ms/step - loss: 0.3965 - accuracy: 0.8404 - val_loss: 0.4237 - val_accuracy: 0.8263
# Epoch 12/15
# 375/375 [==============================] - 135s 356ms/step - loss: 0.3681 - accuracy: 0.8541 - val_loss: 0.3802 - val_accuracy: 0.8526
# Epoch 13/15
# 375/375 [==============================] - 135s 354ms/step - loss: 0.3456 - accuracy: 0.8648 - val_loss: 0.3657 - val_accuracy: 0.8599
# Epoch 14/15
# 375/375 [==============================] - 135s 354ms/step - loss: 0.3348 - accuracy: 0.8705 - val_loss: 0.3530 - val_accuracy: 0.8667
# Epoch 15/15
# 375/375 [==============================] - 135s 354ms/step - loss: 0.3138 - accuracy: 0.8790 - val_loss: 0.3479 - val_accuracy: 0.8687

# %%
#-------------------------------------------------------------------------------

print(cb_I02_D003.times)
final_time = 0
for time in cb_I02_D003.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I02_D003.history['accuracy'])))
print('loss => '+ str(min(history_I02_D003.history['loss'])))
print('val_accuracy => '+ str(max(history_I02_D003.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I02_D003.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I02_D003.history['accuracy']
val_acc = history_I02_D003.history['val_accuracy']

loss=history_I02_D003.history['loss']
val_loss=history_I02_D003.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [134.9838206768036, 134.53196358680725, 133.92901039123535, 133.47645378112793, 133.1214029788971, 134.75547170639038, 131.17779803276062, 133.99969124794006, 135.59217166900635, 135.64114046096802, 135.17580342292786, 135.44218254089355, 134.99603748321533, 134.68642473220825, 134.7840564250946]
# El entrenamiento se demoro: 2016.2934291362762 segundos
# El entrenamiento se demoro: 33.60489048560461 minutos
# accuracy => 0.8790029883384705
# loss => 0.31379184126853943
# val_accuracy => 0.8687264919281006
# val_loss => 0.347896546125412

# %% [markdown]
# ## Modelo DS002-I02-D004

# %%
#-------------------------------------------------------------------------------

cb_I02_D004 = TimingCallback()
num_classes = 5
epochs=15

model_I02_D004 = Sequential([
  layers.Conv2D(8, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='sigmoid'),
  layers.Dense(num_classes)
])
model_I02_D004.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I02_D004.summary()


history_I02_D004 = model_I02_D004.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I02_D004]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/15
# 1497/1497 [==============================] - 115s 76ms/step - loss: 1.2861 - accuracy: 0.4601 - val_loss: 1.0435 - val_accuracy: 0.5609
# Epoch 2/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.8977 - accuracy: 0.6272 - val_loss: 0.7548 - val_accuracy: 0.6851
# Epoch 3/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.7236 - accuracy: 0.6963 - val_loss: 0.6909 - val_accuracy: 0.7278
# Epoch 4/15
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.6425 - accuracy: 0.7512 - val_loss: 0.6507 - val_accuracy: 0.7441
# Epoch 5/15
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.5802 - accuracy: 0.7837 - val_loss: 0.5645 - val_accuracy: 0.7841
# Epoch 6/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.5404 - accuracy: 0.8001 - val_loss: 0.5485 - val_accuracy: 0.7896
# Epoch 7/15
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.5037 - accuracy: 0.8122 - val_loss: 0.5054 - val_accuracy: 0.8055
# Epoch 8/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.4624 - accuracy: 0.8264 - val_loss: 0.4658 - val_accuracy: 0.8217
# Epoch 9/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.4339 - accuracy: 0.8343 - val_loss: 0.4368 - val_accuracy: 0.8338
# Epoch 10/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.4133 - accuracy: 0.8426 - val_loss: 0.4298 - val_accuracy: 0.8344
# Epoch 11/15
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.3880 - accuracy: 0.8500 - val_loss: 0.4255 - val_accuracy: 0.8370
# Epoch 12/15
# 1497/1497 [==============================] - 115s 77ms/step - loss: 0.3757 - accuracy: 0.8560 - val_loss: 0.3943 - val_accuracy: 0.8475
# Epoch 13/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.3636 - accuracy: 0.8604 - val_loss: 0.3769 - val_accuracy: 0.8557
# Epoch 14/15
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.3496 - accuracy: 0.8670 - val_loss: 0.3772 - val_accuracy: 0.8537
# Epoch 15/15
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.3425 - accuracy: 0.8685 - val_loss: 0.3648 - val_accuracy: 0.8575

# %%
#-------------------------------------------------------------------------------

print(cb_I02_D004.times)
final_time = 0
for time in cb_I02_D004.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I02_D004.history['accuracy'])))
print('loss => '+ str(min(history_I02_D004.history['loss'])))
print('val_accuracy => '+ str(max(history_I02_D004.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I02_D004.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I02_D004.history['accuracy']
val_acc = history_I02_D004.history['val_accuracy']

loss=history_I02_D004.history['loss']
val_loss=history_I02_D004.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [114.86585807800293, 114.36349630355835, 114.47418880462646, 114.57122468948364, 114.76682901382446, 114.22511267662048, 114.51145696640015, 114.31966280937195, 114.369863986969, 114.17386436462402, 114.65193819999695, 115.16173505783081, 114.02063870429993, 114.36116099357605, 114.86339831352234]
# El entrenamiento se demoro: 1717.7004289627075 segundos
# El entrenamiento se demoro: 28.628340482711792 minutos
# accuracy => 0.8685023784637451
# loss => 0.34248799085617065
# val_accuracy => 0.8574530482292175
# val_loss => 0.3648199737071991

# %% [markdown]
# ## Modelo DS002-I02-D005

# %%
#-------------------------------------------------------------------------------

cb_I02_D005 = TimingCallback()
num_classes = 5
epochs=15

model_I02_D005 = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(16, activation='relu'),
  layers.Dense(num_classes)
])
model_I02_D005.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I02_D005.summary()


history_I02_D005 = model_I02_D005.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I02_D005]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/15
# 1497/1497 [==============================] - 112s 74ms/step - loss: 0.9325 - accuracy: 0.6198 - val_loss: 0.7643 - val_accuracy: 0.6807
# Epoch 2/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.6781 - accuracy: 0.7214 - val_loss: 0.6490 - val_accuracy: 0.7358
# Epoch 3/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.5902 - accuracy: 0.7616 - val_loss: 0.5305 - val_accuracy: 0.7844
# Epoch 4/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.5355 - accuracy: 0.7837 - val_loss: 0.5166 - val_accuracy: 0.7911
# Epoch 5/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.4958 - accuracy: 0.8019 - val_loss: 0.4701 - val_accuracy: 0.8166
# Epoch 6/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.4671 - accuracy: 0.8154 - val_loss: 0.4537 - val_accuracy: 0.8241
# Epoch 7/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.4411 - accuracy: 0.8268 - val_loss: 0.4641 - val_accuracy: 0.8225
# Epoch 8/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.4257 - accuracy: 0.8339 - val_loss: 0.4409 - val_accuracy: 0.8293
# Epoch 9/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.4092 - accuracy: 0.8409 - val_loss: 0.4453 - val_accuracy: 0.8311
# Epoch 10/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.3955 - accuracy: 0.8466 - val_loss: 0.4033 - val_accuracy: 0.8433
# Epoch 11/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.3775 - accuracy: 0.8542 - val_loss: 0.3926 - val_accuracy: 0.8534
# Epoch 12/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.3693 - accuracy: 0.8579 - val_loss: 0.4055 - val_accuracy: 0.8469
# Epoch 13/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.3653 - accuracy: 0.8589 - val_loss: 0.3754 - val_accuracy: 0.8571
# Epoch 14/15
# 1497/1497 [==============================] - 111s 74ms/step - loss: 0.3511 - accuracy: 0.8646 - val_loss: 0.3639 - val_accuracy: 0.8605
# Epoch 15/15
# 1497/1497 [==============================] - 113s 75ms/step - loss: 0.3419 - accuracy: 0.8679 - val_loss: 0.3737 - val_accuracy: 0.8588

# %%
#-------------------------------------------------------------------------------

print(cb_I02_D005.times)
final_time = 0
for time in cb_I02_D005.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I02_D005.history['accuracy'])))
print('loss => '+ str(min(history_I02_D005.history['loss'])))
print('val_accuracy => '+ str(max(history_I02_D005.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I02_D005.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I02_D005.history['accuracy']
val_acc = history_I02_D005.history['val_accuracy']

loss=history_I02_D005.history['loss']
val_loss=history_I02_D005.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [112.46989822387695, 110.69289660453796, 110.74809837341309, 110.76362419128418, 110.85988450050354, 110.89840245246887, 111.10570812225342, 110.63773608207703, 111.17580676078796, 110.711989402771, 110.58779811859131, 110.7643928527832, 110.99290466308594, 111.06355619430542, 112.80889558792114]
# El entrenamiento se demoro: 1666.281592130661 segundos
# El entrenamiento se demoro: 27.77135986884435 minutos
# accuracy => 0.8679178357124329
# loss => 0.3419119417667389
# val_accuracy => 0.8604592680931091
# val_loss => 0.3638920187950134

# %% [markdown]
# ## Modelo DS002-I02-D006

# %%
#-------------------------------------------------------------------------------

cb_I02_D006 = TimingCallback()
num_classes = 5
epochs=20

model_I02_D006 = Sequential([
  layers.Conv2D(8, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='sigmoid'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(32, activation='sigmoid'),
  layers.Dense(num_classes)
])
model_I02_D006.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# model_I02_D006.summary()


history_I02_D006 = model_I02_D006.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[cb_I02_D006]
)

#-------------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 1497/1497 [==============================] - 121s 80ms/step - loss: 1.2368 - accuracy: 0.4694 - val_loss: 0.9660 - val_accuracy: 0.5853
# Epoch 2/20
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.8938 - accuracy: 0.6172 - val_loss: 0.8417 - val_accuracy: 0.6574
# Epoch 3/20
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.7704 - accuracy: 0.6877 - val_loss: 0.7139 - val_accuracy: 0.7166
# Epoch 4/20
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.7180 - accuracy: 0.7081 - val_loss: 0.7048 - val_accuracy: 0.7193
# Epoch 5/20
# 1497/1497 [==============================] - 114s 76ms/step - loss: 0.6889 - accuracy: 0.7152 - val_loss: 0.6555 - val_accuracy: 0.7349
# Epoch 6/20
# 1497/1497 [==============================] - 118s 79ms/step - loss: 0.6631 - accuracy: 0.7234 - val_loss: 0.6459 - val_accuracy: 0.7366
# Epoch 7/20
# 1497/1497 [==============================] - 121s 80ms/step - loss: 0.6375 - accuracy: 0.7347 - val_loss: 0.6079 - val_accuracy: 0.7533
# Epoch 8/20
# 1497/1497 [==============================] - 120s 80ms/step - loss: 0.6199 - accuracy: 0.7415 - val_loss: 0.6098 - val_accuracy: 0.7420
# Epoch 9/20
# 1497/1497 [==============================] - 122s 81ms/step - loss: 0.5957 - accuracy: 0.7547 - val_loss: 0.6422 - val_accuracy: 0.7390
# Epoch 10/20
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.5497 - accuracy: 0.7803 - val_loss: 0.5151 - val_accuracy: 0.7985
# Epoch 11/20
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.5095 - accuracy: 0.7974 - val_loss: 0.4787 - val_accuracy: 0.8096
# Epoch 12/20
# 1497/1497 [==============================] - 123s 82ms/step - loss: 0.4606 - accuracy: 0.8165 - val_loss: 0.4310 - val_accuracy: 0.8295
# Epoch 13/20
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.4266 - accuracy: 0.8321 - val_loss: 0.4026 - val_accuracy: 0.8441
# Epoch 14/20
# 1497/1497 [==============================] - 124s 83ms/step - loss: 0.3978 - accuracy: 0.8441 - val_loss: 0.3945 - val_accuracy: 0.8443
# Epoch 15/20
# 1497/1497 [==============================] - 115s 77ms/step - loss: 0.3773 - accuracy: 0.8497 - val_loss: 0.3705 - val_accuracy: 0.8586
# Epoch 16/20
# 1497/1497 [==============================] - 115s 77ms/step - loss: 0.3597 - accuracy: 0.8590 - val_loss: 0.3564 - val_accuracy: 0.8637
# Epoch 17/20
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.3474 - accuracy: 0.8649 - val_loss: 0.3565 - val_accuracy: 0.8641
# Epoch 18/20
# 1497/1497 [==============================] - 115s 76ms/step - loss: 0.3377 - accuracy: 0.8675 - val_loss: 0.3132 - val_accuracy: 0.8780
# Epoch 19/20
# 1497/1497 [==============================] - 120s 80ms/step - loss: 0.3237 - accuracy: 0.8746 - val_loss: 0.3224 - val_accuracy: 0.8756
# Epoch 20/20
# 1497/1497 [==============================] - 118s 79ms/step - loss: 0.3134 - accuracy: 0.8764 - val_loss: 0.2984 - val_accuracy: 0.8863

# %%
#-------------------------------------------------------------------------------

print(cb_I02_D006.times)
final_time = 0
for time in cb_I02_D006.times:
  final_time += time
print('El entrenamiento se demoro: ' +str(final_time)+' segundos')
final_time= final_time/60
print('El entrenamiento se demoro: ' +str(final_time)+' minutos')
print('accuracy => '+ str(max(history_I02_D006.history['accuracy'])))
print('loss => '+ str(min(history_I02_D006.history['loss'])))
print('val_accuracy => '+ str(max(history_I02_D006.history['val_accuracy'])))
print('val_loss => '+ str(min(history_I02_D006.history['val_loss'])))

#-------------------------------------------------------------------------------

acc = history_I02_D006.history['accuracy']
val_acc = history_I02_D006.history['val_accuracy']

loss=history_I02_D006.history['loss']
val_loss=history_I02_D006.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [120.6585021018982, 123.14734506607056, 113.610764503479, 114.39610457420349, 114.09305787086487, 118.16315031051636, 120.73725271224976, 120.03169989585876, 121.98977398872375, 122.71774816513062, 123.02390646934509, 122.66838955879211, 124.44166088104248, 124.17272543907166, 115.01476526260376, 115.028071641922, 114.62666535377502, 114.88557529449463, 120.1383867263794, 118.11421990394592]
# El entrenamiento se demoro: 2381.6597657203674 segundos
# El entrenamiento se demoro: 39.69432942867279 minutos
# accuracy => 0.8763517141342163
# loss => 0.3134159445762634
# val_accuracy => 0.8862630724906921
# val_loss => 0.2983795702457428
